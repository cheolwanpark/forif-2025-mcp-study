# %%
# Package 설치
# %pip install --upgrade pip
# %pip install requests requests_html lxml_html_clean
KAKAO_API_KEY = "600899c3c380c0e5c408233b2342609e" # 본인의 카카오 API 키를 입력하세요.
# Out:
# Requirement already satisfied: pip in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (25.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (2.32.5)
# Requirement already satisfied: requests_html in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (0.10.0)
# Requirement already satisfied: lxml_html_clean in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from requests) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from requests) (2025.8.3)
# Requirement already satisfied: pyquery in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from requests_html) (2.0.1)
# Requirement already satisfied: fake-useragent in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from requests_html) (2.2.0)
# Requirement already satisfied: parse in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from requests_html) (1.20.2)
# Requirement already satisfied: bs4 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from requests_html) (0.0.2)
# Requirement already satisfied: w3lib in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from requests_html) (2.3.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from requests_html) (2.0.0)
# Requirement already satisfied: lxml in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from lxml_html_clean) (6.0.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from pyppeteer>=0.0.14->requests_html) (8.7.0)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from pyppeteer>=0.0.14->requests_html) (11.1.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from pyppeteer>=0.0.14->requests_html) (4.67.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from pyppeteer>=0.0.14->requests_html) (10.4)
# Requirement already satisfied: typing-extensions in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests_html) (4.15.0)
# Requirement already satisfied: zipp>=3.20 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.23.0)
# Requirement already satisfied: beautifulsoup4 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from bs4->requests_html) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from beautifulsoup4->bs4->requests_html) (2.8)
# Requirement already satisfied: cssselect>=1.2.0 in /Users/cheolwanpark/Documents/Projects/forif-2025-mcp-study/.venv/lib/python3.13/site-packages (from pyquery->requests_html) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 지명 > 주소 + 좌표 변환
import requests
from dataclasses import dataclass

@dataclass
class Location:
    lat: float
    lon: float
    name: str

def get_location(query: str) -> Location | None:
    url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": query,
        "format": "json",
        "addressdetails": 1,
        "limit": 1
    }
    r = requests.get(url, params=params, headers={"User-Agent": "my-app"})
    data = r.json()
    if data:
        return Location(
            lat=data[0]["lat"],
            lon=data[0]["lon"],
            name=data[0]["name"]
        )
    return None

print(get_location("강남역"))
print(get_location("한양대학교"))
# Out:
# Location(lat='37.4942635', lon='127.0296699', name='강남역')
# Location(lat='37.5569876', lon='127.0470893', name='한양대학교 서울캠퍼스')

# %%
# KaKao API 키워드 검색

import requests
from dataclasses import dataclass

@dataclass
class Place:
    name: str = ""
    category: str = ""
    phone: str = ""
    url: str = ""

def search_place(keyword: str, loc: Location, radius: int = 2000) -> list[Place] | None:
    headers = {
        "Authorization": f"KakaoAK {KAKAO_API_KEY}"
    }
    response = requests.get(
        "https://dapi.kakao.com/v2/local/search/keyword.json", 
        headers=headers, 
        params={
        "query": keyword,
        "x": loc.lon,
        "y": loc.lat,
        "radius": radius,
    })

    if response.status_code != 200:
        return None
    response = response.json()
    
    places = []
    if response.get("documents"):
        for doc in response["documents"]:
            places.append(Place(
                name=doc["place_name"],
                category=doc["category_name"],
                phone=doc["phone"],
                url=doc["place_url"]
            ))
    return places

location = get_location("한양대학교")
if location:
    places = search_place("카페", location)
    for place in places:
        print(place)
# Out:
# Place(name='카페,사근', category='음식점 > 카페', phone='02-2299-5391', url='http://place.map.kakao.com/684753744')
# Place(name='카페소재', category='음식점 > 카페', phone='02-6104-9297', url='http://place.map.kakao.com/320019021')
# Place(name='투썸플레이스 한양대학생복지관점', category='음식점 > 카페 > 커피전문점 > 투썸플레이스', phone='02-2292-8880', url='http://place.map.kakao.com/1533084372')
# Place(name='띠앋 형제본점', category='음식점 > 카페 > 커피전문점', phone='010-8429-9308', url='http://place.map.kakao.com/1659384473')
# Place(name='카페루보브', category='음식점 > 카페 > 커피전문점', phone='02-2299-4048', url='http://place.map.kakao.com/186877666')
# Place(name='히어카페', category='음식점 > 카페', phone='', url='http://place.map.kakao.com/459761981')
# Place(name='스타벅스 한양대점', category='음식점 > 카페 > 커피전문점 > 스타벅스', phone='1522-3232', url='http://place.map.kakao.com/7962110')
# Place(name='복고다방 한양여대점', category='음식점 > 카페 > 다방', phone='02-2297-5695', url='http://place.map.kakao.com/72358333')
# Place(name='할리스커피 한양대병원점', category='음식점 > 카페 > 커피전문점 > 할리스', phone='', url='http://place.map.kakao.com/245298350')
# Place(name='타이파', category='음식점 > 카페 > 테마카페 > 디저트카페', phone='0502-5550-9496', url='http://place.map.kakao.com/1334755509')
# Place(name='갈십리', category='음식점 > 카페 > 테마카페 > 디저트카페', phone='0503-7150-3368', url='http://place.map.kakao.com/231920851')
# Place(name='투썸플레이스 용답역점', category='음식점 > 카페 > 커피전문점 > 투썸플레이스', phone='02-6215-3889', url='http://place.map.kakao.com/447162299')
# Place(name='타로카페 드뷔시산장', category='음식점 > 카페 > 테마카페', phone='02-2296-5658', url='http://place.map.kakao.com/15355388')
# Place(name='더스토리지', category='음식점 > 카페', phone='02-6101-1102', url='http://place.map.kakao.com/26573471')
# Place(name='설빙 한양대점', category='음식점 > 카페 > 테마카페 > 디저트카페 > 설빙', phone='02-2282-0053', url='http://place.map.kakao.com/26644887')

# %%
# URL 에서 별점, 영업 여부, 리뷰 수 가져오기
from requests_html import AsyncHTMLSession
from dataclasses import dataclass
import asyncio

@dataclass
class PlaceDetails:
    rating: str = ""
    status: str = ""
    review_count: int = 0

RATING_XPATH = '//*[@id="mainContent"]/div[1]/div[1]/div[2]/div[1]/a/span/span[2]'
STATUS_XPATH = '//*[@id="mainContent"]/div[1]/div[1]/div[3]/div/span[2]'
REVIEW_COUNT_XPATH = '//*[@id="mainContent"]/div[1]/div[1]/div[2]/div[2]/a/span[2]'

session = AsyncHTMLSession()
sem = asyncio.Semaphore(5)  # 무시해도 돼요 (동시 요청 수 제한)

async def fetch_place_details(url: str) -> PlaceDetails | None:
    async with sem: # 무시해도 돼요 (동시 요청 수 제한)
        res = await session.get(url)

        if res.status_code != 200:
            return None
        
        await res.html.arender(sleep=0.5, timeout=5)

        rating = res.html.xpath(RATING_XPATH, first=True)
        status = res.html.xpath(STATUS_XPATH, first=True)
        review_count = res.html.xpath(REVIEW_COUNT_XPATH, first=True)

        rating = rating.text.strip() if rating else "N/A"
        status = status.text.strip() if status else "N/A"
        review_count = "".join(filter(str.isdigit, review_count.text)) if review_count else "N/A"

        return PlaceDetails(
            rating=rating,
            status=status,
            review_count=int(review_count) if review_count and review_count.isdigit() else -1
        )

print(await fetch_place_details("http://place.map.kakao.com/320019021"))
# Out:
# PlaceDetails(rating='N/A', status='N/A', review_count=-1)

# %%
# 키워드로 장소 검색 + 상세 정보 가져오기
from dataclasses import dataclass
import asyncio

@dataclass
class PlaceWithDetails:
    name: str = ""
    category: str = ""
    phone: str = ""
    rating: str = ""
    status: str = ""
    review_count: int = 0

async def search_place_with_details(keyword: str, loc: Location, radius: int = 2000) -> list[PlaceWithDetails] | None:
    places = list(search_place(keyword, loc, radius))
    if not places:
        return []
    
    details = await asyncio.gather(
        *(fetch_place_details(p.url) for p in places)
    )
    results = [
        PlaceWithDetails(
            name=p.name, 
            category=p.category, 
            phone=p.phone, 
            rating=d.rating, 
            status=d.status, 
            review_count=d.review_count
        ) for p, d in zip(places, details) if d is not None
    ]
    # 원래는 아래 코드
    # results = []
    # for place in places:
    #     detail = await fetch_place_details(place.url)
    #     if detail:
    #         results.append(PlaceWithDetails(
    #             name=place.name,
    #             category=place.category,
    #             phone=place.phone,
    #             rating=detail.rating,
    #             status=detail.status,
    #             review_count=detail.review_count
    #         ))
    return results

location = get_location("한양대학교")
if location:
    places = await search_place_with_details("카페", location)
    for place in places:
        print(place)
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[7], line 49
#      47 location = get_location("한양대학교")
#      48 if location:
# ---> 49     places = await search_place_with_details("카페", location)
#      50     for place in places:
#      51         print(place)
#
# Cell In[7], line 19, in search_place_with_details(keyword, loc, radius)
#      16 if not places:
#      17     return []
# ---> 19 details = await asyncio.gather(
#      20     *(fetch_place_details(p.url) for p in places)
#      21 )
#      22 results = [
#      23     PlaceWithDetails(
#      24         name=p.name,
#    (...)     30     ) for p, d in zip(places, details) if d is not None
#      31 ]
#      32 # 원래는 아래 코드
#      33 # results = []
#      34 # for place in places:
#    (...)     43 #             review_count=detail.review_count
#      44 #         ))
#
# Cell In[6], line 21, in fetch_place_details(url)
#      19 async def fetch_place_details(url: str) -> PlaceDetails | None:
#      20     async with sem: # 무시해도 돼요 (동시 요청 수 제한)
# ---> 21         res = await session.get(url)
#      23         if res.status_code != 200:
#      24             return None
#
# CancelledError:
